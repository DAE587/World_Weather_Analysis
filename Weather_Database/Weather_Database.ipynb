# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yulara
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | palkaka
# City not found. Skipping...
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | itarema
# Processing Record 11 of Set 1 | aswan
# Processing Record 12 of Set 1 | katsuura
# Processing Record 13 of Set 1 | kismayo
# Processing Record 14 of Set 1 | cidreira
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | dallas
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | cotonou
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | lorengau
# Processing Record 21 of Set 1 | tres lagoas
# Processing Record 22 of Set 1 | ariquemes
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | haicheng
# Processing Record 27 of Set 1 | richards bay
# Processing Record 28 of Set 1 | ahipara
# Processing Record 29 of Set 1 | balabac
# Processing Record 30 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | karratha
# Processing Record 34 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 1 | beringovskiy
# Processing Record 36 of Set 1 | oksfjord
# Processing Record 37 of Set 1 | oussouye
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | mikhaylovka
# Processing Record 41 of Set 1 | iskilip
# Processing Record 42 of Set 1 | ishinomaki
# Processing Record 43 of Set 1 | mudanjiang
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | sistranda
# Processing Record 47 of Set 1 | garden city
# Processing Record 48 of Set 1 | mayor pablo lagerenza
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | conakry
# Processing Record 2 of Set 2 | jeremie
# Processing Record 3 of Set 2 | maniitsoq
# Processing Record 4 of Set 2 | mount isa
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 2 | tongliao
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | poronaysk
# Processing Record 17 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 2 | sarangani
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | nicoya
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | leua
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | kazanka
# Processing Record 25 of Set 2 | palembang
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | banihal
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | namie
# Processing Record 32 of Set 2 | margate
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | te anau
# Processing Record 35 of Set 2 | esperance
# Processing Record 36 of Set 2 | alta floresta
# Processing Record 37 of Set 2 | mirina
# City not found. Skipping...
# Processing Record 38 of Set 2 | le vauclin
# Processing Record 39 of Set 2 | kieta
# Processing Record 40 of Set 2 | nome
# Processing Record 41 of Set 2 | linchuan
# City not found. Skipping...
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | visakhapatnam
# Processing Record 44 of Set 2 | pasighat
# Processing Record 45 of Set 2 | abeche
# Processing Record 46 of Set 2 | vestmannaeyjar
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | dunda
# Processing Record 50 of Set 2 | slave lake
# Processing Record 1 of Set 3 | constitucion
# Processing Record 2 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 3 | hami
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | pangoa
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | havoysund
# Processing Record 10 of Set 3 | madimba
# Processing Record 11 of Set 3 | busselton
# Processing Record 12 of Set 3 | coxcatlan
# Processing Record 13 of Set 3 | port elizabeth
# Processing Record 14 of Set 3 | cabra
# Processing Record 15 of Set 3 | arlit
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | egvekinot
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | truro
# Processing Record 20 of Set 3 | khatanga
# Processing Record 21 of Set 3 | san luis
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | chilca
# Processing Record 24 of Set 3 | ambon
# Processing Record 25 of Set 3 | pangody
# Processing Record 26 of Set 3 | broken hill
# Processing Record 27 of Set 3 | ostrovnoy
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | samur
# Processing Record 30 of Set 3 | adrar
# Processing Record 31 of Set 3 | soe
# Processing Record 32 of Set 3 | amahai
# Processing Record 33 of Set 3 | kokopo
# Processing Record 34 of Set 3 | hualmay
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | miquelon
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | moron
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | qaanaaq
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | buchanan
# Processing Record 44 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 3 | alice springs
# Processing Record 46 of Set 3 | tabuk
# Processing Record 47 of Set 3 | nador
# Processing Record 48 of Set 3 | san quintin
# Processing Record 49 of Set 3 | ostersund
# Processing Record 50 of Set 3 | yachimata
# Processing Record 1 of Set 4 | puerto escondido
# Processing Record 2 of Set 4 | fairbanks
# Processing Record 3 of Set 4 | ippy
# Processing Record 4 of Set 4 | quatre cocos
# Processing Record 5 of Set 4 | vao
# Processing Record 6 of Set 4 | jaru
# Processing Record 7 of Set 4 | bilibino
# Processing Record 8 of Set 4 | sinnamary
# Processing Record 9 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 4 | jomalig
# City not found. Skipping...
# Processing Record 11 of Set 4 | banes
# Processing Record 12 of Set 4 | buala
# Processing Record 13 of Set 4 | safranbolu
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | turukhansk
# Processing Record 16 of Set 4 | nazilli
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | baghdad
# Processing Record 19 of Set 4 | hit
# Processing Record 20 of Set 4 | conceicao do araguaia
# Processing Record 21 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 4 | belaya gora
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | acapulco
# Processing Record 26 of Set 4 | saint-pierre
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | clyde river
# Processing Record 29 of Set 4 | bac lieu
# Processing Record 30 of Set 4 | klaksvik
# Processing Record 31 of Set 4 | belmonte
# Processing Record 32 of Set 4 | visnes
# Processing Record 33 of Set 4 | shache
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | dakar
# Processing Record 36 of Set 4 | inirida
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | kodiak
# Processing Record 39 of Set 4 | luderitz
# Processing Record 40 of Set 4 | hastings
# Processing Record 41 of Set 4 | kangaatsiaq
# Processing Record 42 of Set 4 | sarkand
# Processing Record 43 of Set 4 | maribondo
# Processing Record 44 of Set 4 | hailey
# Processing Record 45 of Set 4 | nosy varika
# Processing Record 46 of Set 4 | ust-kuyga
# Processing Record 47 of Set 4 | bonnyville
# Processing Record 48 of Set 4 | hamilton
# Processing Record 49 of Set 4 | tuatapere
# Processing Record 50 of Set 4 | kloulklubed
# Processing Record 1 of Set 5 | logan
# Processing Record 2 of Set 5 | kambove
# Processing Record 3 of Set 5 | hudson bay
# Processing Record 4 of Set 5 | saint-felicien
# Processing Record 5 of Set 5 | severo-kurilsk
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | mar del plata
# Processing Record 8 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 5 | pitanga
# Processing Record 10 of Set 5 | jacareacanga
# Processing Record 11 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 5 | tokur
# Processing Record 13 of Set 5 | maltahohe
# Processing Record 14 of Set 5 | lufilufi
# Processing Record 15 of Set 5 | taltal
# Processing Record 16 of Set 5 | mandiana
# Processing Record 17 of Set 5 | champerico
# Processing Record 18 of Set 5 | avera
# Processing Record 19 of Set 5 | sabang
# Processing Record 20 of Set 5 | shubarkuduk
# Processing Record 21 of Set 5 | uyuni
# Processing Record 22 of Set 5 | lompoc
# Processing Record 23 of Set 5 | hofn
# Processing Record 24 of Set 5 | saint-augustin
# Processing Record 25 of Set 5 | matara
# Processing Record 26 of Set 5 | narsaq
# Processing Record 27 of Set 5 | usinsk
# Processing Record 28 of Set 5 | matagami
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | shebekino
# Processing Record 32 of Set 5 | torbay
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | sheregesh
# Processing Record 35 of Set 5 | nadym
# Processing Record 36 of Set 5 | boa vista
# Processing Record 37 of Set 5 | pouebo
# Processing Record 38 of Set 5 | santa vitoria do palmar
# Processing Record 39 of Set 5 | lerwick
# Processing Record 40 of Set 5 | meadville
# Processing Record 41 of Set 5 | belomorsk
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | chicama
# Processing Record 45 of Set 5 | natal
# Processing Record 46 of Set 5 | alyangula
# Processing Record 47 of Set 5 | cody
# Processing Record 48 of Set 5 | santa lucia
# Processing Record 49 of Set 5 | mikhaylovskoye
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 6 | jian
# Processing Record 3 of Set 6 | arraial do cabo
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | homer
# Processing Record 6 of Set 6 | poum
# Processing Record 7 of Set 6 | otse
# Processing Record 8 of Set 6 | port augusta
# Processing Record 9 of Set 6 | staryy nadym
# Processing Record 10 of Set 6 | saratoga springs
# Processing Record 11 of Set 6 | pierre
# Processing Record 12 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 6 | flin flon
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 16 of Set 6 | moa
# Processing Record 17 of Set 6 | sayyan
# Processing Record 18 of Set 6 | sobolevo
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | gat
# Processing Record 21 of Set 6 | nanortalik
# Processing Record 22 of Set 6 | ancud
# Processing Record 23 of Set 6 | borisoglebskiy
# Processing Record 24 of Set 6 | riyadh
# Processing Record 25 of Set 6 | taksimo
# Processing Record 26 of Set 6 | buritis
# Processing Record 27 of Set 6 | vestmanna
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | dunedin
# Processing Record 30 of Set 6 | darnah
# Processing Record 31 of Set 6 | burnie
# Processing Record 32 of Set 6 | wageningen
# Processing Record 33 of Set 6 | buraydah
# Processing Record 34 of Set 6 | valparai
# Processing Record 35 of Set 6 | morant bay
# Processing Record 36 of Set 6 | nouakchott
# Processing Record 37 of Set 6 | terra rica
# Processing Record 38 of Set 6 | telimele
# Processing Record 39 of Set 6 | chalus
# Processing Record 40 of Set 6 | belaguntha
# Processing Record 41 of Set 6 | saldanha
# Processing Record 42 of Set 6 | cabo san lucas
# Processing Record 43 of Set 6 | parkes
# Processing Record 44 of Set 6 | chotila
# Processing Record 45 of Set 6 | baykit
# Processing Record 46 of Set 6 | iralaya
# Processing Record 47 of Set 6 | husavik
# Processing Record 48 of Set 6 | verkhoyansk
# Processing Record 49 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 7 | ubinskoye
# Processing Record 2 of Set 7 | hovd
# Processing Record 3 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 4 of Set 7 | gvarv
# Processing Record 5 of Set 7 | gamba
# Processing Record 6 of Set 7 | sonoita
# Processing Record 7 of Set 7 | wanning
# Processing Record 8 of Set 7 | tottori
# Processing Record 9 of Set 7 | lucera
# Processing Record 10 of Set 7 | saskylakh
# Processing Record 11 of Set 7 | noumea
# Processing Record 12 of Set 7 | tura
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | college
# Processing Record 15 of Set 7 | vicosa
# Processing Record 16 of Set 7 | apollonia
# Processing Record 17 of Set 7 | buguda
# Processing Record 18 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 7 | vallenar
# Processing Record 20 of Set 7 | naze
# Processing Record 21 of Set 7 | mackay
# Processing Record 22 of Set 7 | olivet
# Processing Record 23 of Set 7 | lavrentiya
# Processing Record 24 of Set 7 | isiro
# Processing Record 25 of Set 7 | velyka bahachka
# Processing Record 26 of Set 7 | geilo
# Processing Record 27 of Set 7 | guekedou
# City not found. Skipping...
# Processing Record 28 of Set 7 | colon
# Processing Record 29 of Set 7 | calama
# Processing Record 30 of Set 7 | lebanon
# Processing Record 31 of Set 7 | vila
# Processing Record 32 of Set 7 | kununurra
# Processing Record 33 of Set 7 | wahiawa
# Processing Record 34 of Set 7 | victoria
# Processing Record 35 of Set 7 | chapais
# Processing Record 36 of Set 7 | pevek
# Processing Record 37 of Set 7 | san cristobal
# Processing Record 38 of Set 7 | canutama
# Processing Record 39 of Set 7 | manica
# Processing Record 40 of Set 7 | camocim
# Processing Record 41 of Set 7 | keshan
# City not found. Skipping...
# Processing Record 42 of Set 7 | coihaique
# Processing Record 43 of Set 7 | hobyo
# Processing Record 44 of Set 7 | sioux falls
# Processing Record 45 of Set 7 | najran
# Processing Record 46 of Set 7 | bukama
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 7 | rathdrum
# Processing Record 50 of Set 7 | siavonga
# Processing Record 1 of Set 8 | villa carlos paz
# Processing Record 2 of Set 8 | udarnyy
# Processing Record 3 of Set 8 | elmina
# Processing Record 4 of Set 8 | portland
# Processing Record 5 of Set 8 | wewak
# Processing Record 6 of Set 8 | port lincoln
# Processing Record 7 of Set 8 | lukh
# Processing Record 8 of Set 8 | los llanos de aridane
# Processing Record 9 of Set 8 | geraldton
# Processing Record 10 of Set 8 | sovetskiy
# Processing Record 11 of Set 8 | peterhead
# Processing Record 12 of Set 8 | villamaria
# Processing Record 13 of Set 8 | hervey bay
# Processing Record 14 of Set 8 | port hardy
# Processing Record 15 of Set 8 | sao filipe
# Processing Record 16 of Set 8 | havelock
# Processing Record 17 of Set 8 | tazovskiy
# Processing Record 18 of Set 8 | hasaki
# Processing Record 19 of Set 8 | sakaraha
# Processing Record 20 of Set 8 | namibe
# Processing Record 21 of Set 8 | tacuarembo
# Processing Record 22 of Set 8 | komsomolskiy
# Processing Record 23 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 24 of Set 8 | sabya
# Processing Record 25 of Set 8 | kruisfontein
# Processing Record 26 of Set 8 | mana
# Processing Record 27 of Set 8 | bay roberts
# Processing Record 28 of Set 8 | iqaluit
# Processing Record 29 of Set 8 | wilmington
# Processing Record 30 of Set 8 | chuy
# Processing Record 31 of Set 8 | harper
# Processing Record 32 of Set 8 | leningradskiy
# Processing Record 33 of Set 8 | rome
# Processing Record 34 of Set 8 | iberia
# Processing Record 35 of Set 8 | kailua
# Processing Record 36 of Set 8 | nkan
# Processing Record 37 of Set 8 | dingle
# Processing Record 38 of Set 8 | camabatela
# Processing Record 39 of Set 8 | monchegorsk
# Processing Record 40 of Set 8 | hirara
# Processing Record 41 of Set 8 | necochea
# Processing Record 42 of Set 8 | araouane
# Processing Record 43 of Set 8 | alihe
# Processing Record 44 of Set 8 | campos novos
# Processing Record 45 of Set 8 | puri
# Processing Record 46 of Set 8 | mopipi
# Processing Record 47 of Set 8 | cuenca
# Processing Record 48 of Set 8 | sept-iles
# Processing Record 49 of Set 8 | ushtobe
# Processing Record 50 of Set 8 | kamina
# Processing Record 1 of Set 9 | tahta
# Processing Record 2 of Set 9 | codrington
# Processing Record 3 of Set 9 | talnakh
# Processing Record 4 of Set 9 | kiri buru
# Processing Record 5 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 9 | chihuahua
# Processing Record 7 of Set 9 | ust-nera
# Processing Record 8 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 9 of Set 9 | ferrol
# Processing Record 10 of Set 9 | biak
# Processing Record 11 of Set 9 | omboue
# Processing Record 12 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 9 | comodoro rivadavia
# Processing Record 14 of Set 9 | salalah
# Processing Record 15 of Set 9 | port blair
# Processing Record 16 of Set 9 | aginskoye
# Processing Record 17 of Set 9 | peniche
# Processing Record 18 of Set 9 | majalgaon
# Processing Record 19 of Set 9 | allapalli
# Processing Record 20 of Set 9 | mugur-aksy
# Processing Record 21 of Set 9 | lagoa
# Processing Record 22 of Set 9 | guerrero negro
# Processing Record 23 of Set 9 | pechora
# Processing Record 24 of Set 9 | goksun
# Processing Record 25 of Set 9 | neiafu
# Processing Record 26 of Set 9 | butembo
# Processing Record 27 of Set 9 | quartucciu
# Processing Record 28 of Set 9 | la fleche
# Processing Record 29 of Set 9 | tomatlan
# Processing Record 30 of Set 9 | pocatello
# Processing Record 31 of Set 9 | vermillion
# Processing Record 32 of Set 9 | airai
# Processing Record 33 of Set 9 | berlevag
# Processing Record 34 of Set 9 | borazjan
# Processing Record 35 of Set 9 | perry
# Processing Record 36 of Set 9 | idrinskoye
# Processing Record 37 of Set 9 | kayerkan
# Processing Record 38 of Set 9 | puerto narino
# Processing Record 39 of Set 9 | yeniseysk
# Processing Record 40 of Set 9 | kokkola
# Processing Record 41 of Set 9 | shitanjing
# Processing Record 42 of Set 9 | coquimbo
# Processing Record 43 of Set 9 | kirakira
# Processing Record 44 of Set 9 | shenzhen
# Processing Record 45 of Set 9 | nanga eboko
# Processing Record 46 of Set 9 | palmeiras de goias
# Processing Record 47 of Set 9 | xifeng
# Processing Record 48 of Set 9 | sinjai
# Processing Record 49 of Set 9 | antagan
# City not found. Skipping...
# Processing Record 50 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 10 | pilar
# Processing Record 2 of Set 10 | cadiz
# Processing Record 3 of Set 10 | buin
# Processing Record 4 of Set 10 | mokhsogollokh
# Processing Record 5 of Set 10 | tarko-sale
# Processing Record 6 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 10 | okmulgee
# Processing Record 8 of Set 10 | zhigansk
# Processing Record 9 of Set 10 | haines junction
# Processing Record 10 of Set 10 | mabaruma
# Processing Record 11 of Set 10 | ilulissat
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | lasa
# Processing Record 14 of Set 10 | beverley
# Processing Record 15 of Set 10 | asau
# Processing Record 16 of Set 10 | suntar
# Processing Record 17 of Set 10 | gazli
# Processing Record 18 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 10 | milkovo
# Processing Record 21 of Set 10 | tranas
# Processing Record 22 of Set 10 | beipiao
# Processing Record 23 of Set 10 | humberto de campos
# Processing Record 24 of Set 10 | kampene
# Processing Record 25 of Set 10 | marawi
# Processing Record 26 of Set 10 | qixia
# Processing Record 27 of Set 10 | san rafael
# Processing Record 28 of Set 10 | seabra
# Processing Record 29 of Set 10 | leh
# Processing Record 30 of Set 10 | ruteng
# Processing Record 31 of Set 10 | uruzgan
# Processing Record 32 of Set 10 | yamada
# Processing Record 33 of Set 10 | bathsheba
# Processing Record 34 of Set 10 | honiara
# Processing Record 35 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 10 | mogadishu
# Processing Record 37 of Set 10 | esmeraldas
# Processing Record 38 of Set 10 | sola
# Processing Record 39 of Set 10 | santa maria do suacui
# Processing Record 40 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 10 | marsh harbour
# Processing Record 42 of Set 10 | fortuna foothills
# Processing Record 43 of Set 10 | shimoni
# Processing Record 44 of Set 10 | valentin gomez farias
# Processing Record 45 of Set 10 | vila velha
# Processing Record 46 of Set 10 | nishihara
# Processing Record 47 of Set 10 | borba
# Processing Record 48 of Set 10 | bubaque
# Processing Record 49 of Set 10 | khasan
# Processing Record 50 of Set 10 | yasothon
# Processing Record 1 of Set 11 | bakel
# Processing Record 2 of Set 11 | sampit
# Processing Record 3 of Set 11 | prince rupert
# Processing Record 4 of Set 11 | pacific grove
# Processing Record 5 of Set 11 | santa cruz de tenerife
# Processing Record 6 of Set 11 | naryan-mar
# Processing Record 7 of Set 11 | visby
# Processing Record 8 of Set 11 | saint-joseph
# Processing Record 9 of Set 11 | blagoyevo
# Processing Record 10 of Set 11 | fortuna
# Processing Record 11 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 12 of Set 11 | vajszlo
# Processing Record 13 of Set 11 | labrea
# Processing Record 14 of Set 11 | taoudenni
# Processing Record 15 of Set 11 | mookane
# Processing Record 16 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 11 | ajdabiya
# Processing Record 18 of Set 11 | carauari
# Processing Record 19 of Set 11 | kennett
# Processing Record 20 of Set 11 | baruun-urt
# Processing Record 21 of Set 11 | lincoln
# Processing Record 22 of Set 11 | makakilo city
# Processing Record 23 of Set 11 | cairns
# Processing Record 24 of Set 11 | minab
# Processing Record 25 of Set 11 | kobelyaky
# Processing Record 26 of Set 11 | escanaba
# Processing Record 27 of Set 11 | rudbar
# Processing Record 28 of Set 11 | san patricio
# Processing Record 29 of Set 11 | camargo
# Processing Record 30 of Set 11 | timra
# Processing Record 31 of Set 11 | longyearbyen
# Processing Record 32 of Set 11 | toila
# Processing Record 33 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 11 | pafos
# Processing Record 35 of Set 11 | paita
# Processing Record 36 of Set 11 | mwinilunga
# Processing Record 37 of Set 11 | goma
# Processing Record 38 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 11 | zaozerne
# Processing Record 41 of Set 11 | mlonggo
# Processing Record 42 of Set 11 | antalaha
# Processing Record 43 of Set 11 | trairi
# Processing Record 44 of Set 11 | westport
# Processing Record 45 of Set 11 | annau
# Processing Record 46 of Set 11 | moranbah
# Processing Record 47 of Set 11 | chibombo
# Processing Record 48 of Set 11 | ketchikan
# Processing Record 49 of Set 11 | karur
# Processing Record 50 of Set 11 | muroto
# Processing Record 1 of Set 12 | rio gallegos
# Processing Record 2 of Set 12 | esso
# Processing Record 3 of Set 12 | uzhur
# Processing Record 4 of Set 12 | bilma
# Processing Record 5 of Set 12 | aquiraz
# Processing Record 6 of Set 12 | emmett
# Processing Record 7 of Set 12 | vuktyl
# Processing Record 8 of Set 12 | oranjemund
# Processing Record 9 of Set 12 | srandakan
# Processing Record 10 of Set 12 | rocha
# Processing Record 11 of Set 12 | saint pete beach
# Processing Record 12 of Set 12 | touros
# Processing Record 13 of Set 12 | umea
# Processing Record 14 of Set 12 | yar-sale
# Processing Record 15 of Set 12 | road town
# Processing Record 16 of Set 12 | san ramon
# Processing Record 17 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 18 of Set 12 | nelson bay
# Processing Record 19 of Set 12 | marfino
# Processing Record 20 of Set 12 | baturaja
# Processing Record 21 of Set 12 | tete
# Processing Record 22 of Set 12 | algiers
# Processing Record 23 of Set 12 | tabou
# Processing Record 24 of Set 12 | louis trichardt
# Processing Record 25 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 12 | seymchan
# Processing Record 27 of Set 12 | konskie
# Processing Record 28 of Set 12 | coahuayana
# Processing Record 29 of Set 12 | turayf
# Processing Record 30 of Set 12 | nangomba
# Processing Record 31 of Set 12 | paracuru
# Processing Record 32 of Set 12 | smolenskoye
# Processing Record 33 of Set 12 | high level
# Processing Record 34 of Set 12 | vilyuysk
# Processing Record 35 of Set 12 | anchorage
# Processing Record 36 of Set 12 | kadingilan
# Processing Record 37 of Set 12 | ucluelet
# Processing Record 38 of Set 12 | sumenep
# Processing Record 39 of Set 12 | lata
# Processing Record 40 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 12 | abhar
# Processing Record 42 of Set 12 | rawson
# Processing Record 43 of Set 12 | zhanaozen
# Processing Record 44 of Set 12 | iranshahr
# Processing Record 45 of Set 12 | taywarah
# Processing Record 46 of Set 12 | port said
# Processing Record 47 of Set 12 | koutiala
# Processing Record 48 of Set 12 | oreanda
# City not found. Skipping...
# Processing Record 49 of Set 12 | mayo
# Processing Record 50 of Set 12 | stege
# Processing Record 1 of Set 13 | enfield
# Processing Record 2 of Set 13 | guadalupe y calvo
# Processing Record 3 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 13 | ouegoa
# Processing Record 5 of Set 13 | bandarbeyla
# Processing Record 6 of Set 13 | pontianak
# Processing Record 7 of Set 13 | pangkalanbuun
# Processing Record 8 of Set 13 | barra dos coqueiros
# Processing Record 9 of Set 13 | damietta
# Processing Record 10 of Set 13 | pyinmana
# Processing Record 11 of Set 13 | sambava
# Processing Record 12 of Set 13 | huadian
# Processing Record 13 of Set 13 | shelby
# Processing Record 14 of Set 13 | mangrol
# Processing Record 15 of Set 13 | abu zabad
# Processing Record 16 of Set 13 | caxito
# Processing Record 17 of Set 13 | biloela
# Processing Record 18 of Set 13 | dicamay
# Processing Record 19 of Set 13 | mehamn
# Processing Record 20 of Set 13 | kisangani
# Processing Record 21 of Set 13 | tezu
# Processing Record 22 of Set 13 | puerto quijarro
# Processing Record 23 of Set 13 | cooma
# Processing Record 24 of Set 13 | doka
# Processing Record 25 of Set 13 | hole narsipur
# Processing Record 26 of Set 13 | mizpe ramon
# City not found. Skipping...
# Processing Record 27 of Set 13 | cururupu
# Processing Record 28 of Set 13 | harrison
# Processing Record 29 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | pangnirtung
# Processing Record 32 of Set 13 | boden
# Processing Record 33 of Set 13 | gunnedah
# Processing Record 34 of Set 13 | vanavara
# Processing Record 35 of Set 13 | alappuzha
# Processing Record 36 of Set 13 | kilmez
# City not found. Skipping...
# Processing Record 37 of Set 13 | dabhol
# Processing Record 38 of Set 13 | elko
# Processing Record 39 of Set 13 | atar
# Processing Record 40 of Set 13 | lazarev
# Processing Record 41 of Set 13 | huancabamba
# Processing Record 42 of Set 13 | pryazha
# Processing Record 43 of Set 13 | carroll
# Processing Record 44 of Set 13 | evensk
# Processing Record 45 of Set 13 | bodden town
# Processing Record 46 of Set 13 | chanika
# Processing Record 47 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 48 of Set 13 | manaul
# Processing Record 49 of Set 13 | okhotsk
# Processing Record 50 of Set 13 | rio cuarto
# Processing Record 1 of Set 14 | touba
# Processing Record 2 of Set 14 | nigde
# Processing Record 3 of Set 14 | port-gentil
# Processing Record 4 of Set 14 | san fernando
# Processing Record 5 of Set 14 | inongo
# Processing Record 6 of Set 14 | bojnurd
# Processing Record 7 of Set 14 | uporovo
# Processing Record 8 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 14 | mbanza-ngungu
# Processing Record 10 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 11 of Set 14 | meulaboh
# Processing Record 12 of Set 14 | anadyr
# Processing Record 13 of Set 14 | varberg
# Processing Record 14 of Set 14 | cap-aux-meules
# Processing Record 15 of Set 14 | luwingu
# Processing Record 16 of Set 14 | arman
# Processing Record 17 of Set 14 | jardim
# Processing Record 18 of Set 14 | bellevue
# Processing Record 19 of Set 14 | bayir
# Processing Record 20 of Set 14 | petukhovo
# Processing Record 21 of Set 14 | fort morgan
# Processing Record 22 of Set 14 | mizdah
# Processing Record 23 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 14 | pauini
# Processing Record 25 of Set 14 | altagracia de orituco
# Processing Record 26 of Set 14 | bibiani
# Processing Record 27 of Set 14 | dicabisagan
# Processing Record 28 of Set 14 | gemena
# Processing Record 29 of Set 14 | suamico
# Processing Record 30 of Set 14 | juneau
# Processing Record 31 of Set 14 | jacksonville beach
# Processing Record 32 of Set 14 | wajir
# Processing Record 33 of Set 14 | paro
# Processing Record 34 of Set 14 | manggar
# Processing Record 35 of Set 14 | iquique
# Processing Record 36 of Set 14 | tessalit
# Processing Record 37 of Set 14 | teguldet
# Processing Record 38 of Set 14 | tecoanapa
# Processing Record 39 of Set 14 | celestun
# Processing Record 40 of Set 14 | detchino
# Processing Record 41 of Set 14 | montepuez
# Processing Record 42 of Set 14 | waingapu
# Processing Record 43 of Set 14 | eyl
# Processing Record 44 of Set 14 | lekoni
# Processing Record 45 of Set 14 | guimar
# Processing Record 46 of Set 14 | auki
# Processing Record 47 of Set 14 | benbrook
# Processing Record 48 of Set 14 | lazaro cardenas
# Processing Record 49 of Set 14 | bambanglipuro
# Processing Record 50 of Set 14 | tsumeb
# Processing Record 1 of Set 15 | onega
# Processing Record 2 of Set 15 | soc trang
# Processing Record 3 of Set 15 | santa cruz
# Processing Record 4 of Set 15 | tsiroanomandidy
# Processing Record 5 of Set 15 | amga
# Processing Record 6 of Set 15 | rodrigues alves
# Processing Record 7 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 15 | besikduzu
# Processing Record 9 of Set 15 | castelnau-le-lez
# Processing Record 10 of Set 15 | espanola
# Processing Record 11 of Set 15 | dovolnoye
# Processing Record 12 of Set 15 | xuddur
# Processing Record 13 of Set 15 | yialos
# City not found. Skipping...
# Processing Record 14 of Set 15 | boralday
# Processing Record 15 of Set 15 | lambarene
# Processing Record 16 of Set 15 | igarka
# Processing Record 17 of Set 15 | kavaratti
# Processing Record 18 of Set 15 | yarmouth
# Processing Record 19 of Set 15 | goderich
# Processing Record 20 of Set 15 | lyubytino
# Processing Record 21 of Set 15 | beauceville
# Processing Record 22 of Set 15 | huron
# Processing Record 23 of Set 15 | fuerte olimpo
# Processing Record 24 of Set 15 | rochester
# Processing Record 25 of Set 15 | huarmey
# Processing Record 26 of Set 15 | yabrud
# Processing Record 27 of Set 15 | angoche
# Processing Record 28 of Set 15 | kinlochleven
# Processing Record 29 of Set 15 | santo antonio do ica
# Processing Record 30 of Set 15 | potsdam
# Processing Record 31 of Set 15 | beloha
# Processing Record 32 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 15 | isetskoye
# Processing Record 34 of Set 15 | tecolutla
# Processing Record 35 of Set 15 | esfarayen
# Processing Record 36 of Set 15 | raudeberg
# Processing Record 37 of Set 15 | soubre
# Processing Record 38 of Set 15 | tongchuan
# Processing Record 39 of Set 15 | mae chan
# Processing Record 40 of Set 15 | awjilah
# Processing Record 41 of Set 15 | eureka
# Processing Record 42 of Set 15 | rudsar
# Processing Record 43 of Set 15 | sotouboua
# Processing Record 44 of Set 15 | brae
# Processing Record 45 of Set 15 | tautira
# Processing Record 46 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 15 | laguna
# Processing Record 48 of Set 15 | tshikapa
# Processing Record 49 of Set 15 | wuan
# Processing Record 50 of Set 15 | ayan
# Processing Record 1 of Set 16 | toungoo
# City not found. Skipping...
# Processing Record 2 of Set 16 | akyab
# Processing Record 3 of Set 16 | malpe
# Processing Record 4 of Set 16 | merauke
# Processing Record 5 of Set 16 | bingol
# Processing Record 6 of Set 16 | mareeba
# Processing Record 7 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 16 | porto torres
# Processing Record 9 of Set 16 | leo
# Processing Record 10 of Set 16 | malindi
# Processing Record 11 of Set 16 | san joaquin
# Processing Record 12 of Set 16 | santa maria a vico
# Processing Record 13 of Set 16 | chanderi
# Processing Record 14 of Set 16 | kundiawa
# Processing Record 15 of Set 16 | piacabucu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Yulara -25.2406  130.9889     67.84        56           0        2.30
# 1     Castro -24.7911  -50.0119     75.07        65          37        5.53
# 2      Sitka  57.0531 -135.3300     37.29        52         100        8.05
# 3  Cape Town -33.9258   18.4232     68.09        61           0        8.05
# 4      Kapaa  22.0752 -159.3190     77.18        71           0        1.99
# 5    Rikitea -23.1203 -134.9692     79.21        72          89       18.81
# 6   Thompson  55.7435  -97.8558     -9.24        70         100       14.97
# 7    Itarema  -2.9248  -39.9167     83.48        64          89       10.38
# 8      Aswan  24.0934   32.9070     54.14        34           0       11.36
# 9   Katsuura  35.1333  140.3000     37.42        96         100       22.62
#
#   Weather Description Country
# 0           clear sky      AU
# 1    scattered clouds      BR
# 2     overcast clouds      US
# 3           clear sky      ZA
# 4           clear sky      US
# 5     overcast clouds      PF
# 6     overcast clouds      CA
# 7     overcast clouds      BR
# 8           clear sky      EG
# 9     overcast clouds      JP

# %%
# Reorder the columns in the city_data_df.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Yulara      AU -25.2406  130.9889     67.84        56
# 1                Castro      BR -24.7911  -50.0119     75.07        65
# 2                 Sitka      US  57.0531 -135.3300     37.29        52
# 3             Cape Town      ZA -33.9258   18.4232     68.09        61
# 4                 Kapaa      US  22.0752 -159.3190     77.18        71
# ..                  ...     ...      ...       ...       ...       ...
# 690         San Joaquin      US  37.9333 -121.3011     76.15        46
# 691  Santa Maria A Vico      IT  41.0255   14.4654     51.17        81
# 692            Chanderi      IN  24.7167   78.1333     52.81        55
# 693            Kundiawa      PG  -6.0167  144.9667     63.97        97
# 694           Piacabucu      BR -10.4056  -36.4344     81.50        71
#
#      Cloudiness  Wind Speed Weather Description
# 0             0        2.30           clear sky
# 1            37        5.53    scattered clouds
# 2           100        8.05     overcast clouds
# 3             0        8.05           clear sky
# 4             0        1.99           clear sky
# ..          ...         ...                 ...
# 690           3        2.62           clear sky
# 691           0        1.21           clear sky
# 692           0        1.28           clear sky
# 693         100        0.76     overcast clouds
# 694           3       13.29           clear sky
#
# [695 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
